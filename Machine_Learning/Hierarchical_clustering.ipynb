# %%
import pandas as pd 
import numpy as np
import time
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt 

df = pd.read_csv("../../Tascas/Data/DelayedFlights.csv", nrows=1e4)
newdf = df[["AirTime","DepDelay"]].dropna()

# %%
newdf = df[["AirTime","Distance","TaxiOut", "ArrDelay","DepDelay"]].dropna()

# %%
# euclidean / L1 / L2 / manhattan / cosine / precomputed
# affinitty="L1, linkage="Complete

clstr = AgglomerativeClustering(n_clusters=20)
clstr.fit(newdf)
# Out:
# AgglomerativeClustering(n_clusters=20)

# %%
plt.scatter(newdf["AirTime"], newdf["DepDelay"], c = clstr.fit_predict(newdf))
plt.show()

# %%
alldf = pd.read_csv("../../Tascas/Data/DelayedFlights.csv", nrows=2e4)[["AirTime","DepDelay"]].dropna()
clstr.fit_predict(newdf)[0:10]
# Out:
# array([ 2,  2,  3,  3,  2, 17,  8,  8,  4, 14])
