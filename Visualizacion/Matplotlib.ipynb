# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

df = pd.read_csv("../../Tascas/Data/DelayedFlights.csv", nrows=100000)

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0                 N         0           NaN           NaN      NaN
# 1                 N         0           NaN           NaN      NaN
# 2                 N         0           NaN           NaN      NaN
# 3                 N         0           2.0           0.0      0.0
# 4                 N         0           NaN           NaN      NaN
#
#   SecurityDelay  LateAircraftDelay
# 0           NaN                NaN
# 1           NaN                NaN
# 2           NaN                NaN
# 3           0.0               32.0
# 4           NaN                NaN
#
# [5 rows x 30 columns]

# %%
data = np.unique(df.UniqueCarrier, return_counts = True)
data
# Out:
# (array(['DL', 'OH', 'OO', 'UA', 'US', 'WN', 'XE', 'YV'], dtype=object),
#  array([ 4140,  4364, 15326, 14970,  9789, 35247, 10260,  5904]))

# %%
plt.pie(x = data[1],labels = data[0])
plt.show()

# %%
plt.pie(x = data[1],
    labels = data[0],
    colors = ["Red", "Green"],
    shadow = True,
    radius = 2,
    startangle=90)
plt.show()

# %%
import seaborn as sns
np.random.seed(0)

df = pd.read_csv("../../Tascas/Data/DelayedFlights.csv", nrows=1000000)
df = df.sample(frac=1).head(100)

# %%
plt.scatter(x=df.DayofMonth, y= df.ArrDelay, s = df.Distance)

# %%
plt.scatter(x=df.DayofMonth, y= df.ArrDelay, s = df.Distance, alpha= .3) #opacidad

# %%
plt.scatter(x=df.DayofMonth, y= df.ArrDelay, s = df.Distance, alpha= .3, c= df.DayOfWeek.isin([6,7])) #fin de semana

# %%
plt.scatter(x=df.DayofMonth, y= df.ArrDelay, s = df.Distance, alpha= .3, c= df.DayOfWeek.isin([6,7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Día del Mes")
plt.ylabel("Retraso al llegar")
# Out:
# Text(0, 0.5, 'Retraso al llegar')

# %%
plt.scatter(x=df.DayofMonth, y= df.ArrDelay, s = df.Distance, alpha= .3, c= df.DayOfWeek.isin([6,7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Día del Mes")
plt.ylabel("Retraso al llegar")
plt.ylim([0,150]) #zoom scala
# Out:
# (0.0, 150.0)

# %%
plt.scatter(x=df.DayofMonth, y= df.ArrDelay, s = df.Distance, alpha= .3, c= df.DayOfWeek.isin([6,7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Día del Mes")
plt.ylabel("Retraso al llegar")
plt.ylim([0,150])
plt.xticks([0,15,30]) #numero de marcas en x
# Out:
# ([<matplotlib.axis.XTick at 0x7f809c148be0>,
#   <matplotlib.axis.XTick at 0x7f808e168730>,
#   <matplotlib.axis.XTick at 0x7f808e168910>],
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
plt.scatter(x=df.DayofMonth, y= df.ArrDelay, s = df.Distance, alpha= .3, c= df.DayOfWeek.isin([6,7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Día del Mes")
plt.ylabel("Retraso al llegar")
plt.ylim([0,150])
plt.xticks([0,15,30]) 
plt.text(x=28,y=120,s="Mi Vuelo")
plt.show() # por convencion
# Out:
# Text(28, 120, 'Mi Vuelo')

# %% [markdown]
# # HERRAMIENTAS AVANZADAS

# %%
df = pd.read_csv("../../Tascas/Data/DelayedFlights.csv", nrows=100000)
data = np.unique(df.DayOfWeek, return_counts = True)

# %%
labs=["Lun","Mar","Mie","Jue","Vie","Sab","Dom" ]
data
# Out:
# (array([1, 2, 3, 4, 5, 6, 7]),
#  array([13251, 14581, 14758, 19515, 14624,  9618, 13653]))

# %%
plt.pie(x=data[1],
    labels=data[0],
    radius = 1.5,
    colors= ["Red","Green","Orange","Blue","Gray","Pink","Black"],
    startangle=90)
plt.show()

# %%
plt.pie(x=data[1],
    labels=labs,
    radius = 1.5,
    colors= ["Red","Green","Orange","Blue","Gray","Pink","Black"],
    startangle=90)  
plt.show()   #cambio etiquetas

# %%
plt.pie(x=data[1],
    labels=labs, 
    radius = 1.5,
    colors= sns.color_palette("hls",7),
    startangle=90)  
plt.show()  #mejora d ecolores

# %%
plt.pie(x=data[1],
    labels=labs,
    radius = 1.5,
    colors= sns.color_palette("hls",7),
    explode = (0,0,0,0.2,0,0,0.1),
    startangle=90)
plt.show()  #extrae quesito

# %%
plt.pie(x=data[1],
    labels=labs,
    radius = 1.5,
    colors= sns.color_palette("hls",7),
    explode = (0,0,0,0.2,0,0,0.1),
    startangle=90,
    autopct = "%1.1f%%")
plt.show()  # Tantos porciento %

# %%
plt.pie(x=data[1],
   # labels=labs,
    radius = 0.6,
    colors= sns.color_palette("hls",7),
    explode = (0,0,0,0.2,0,0,0.1),
    startangle=90,
    autopct = "%1.1f%%")
plt.legend(loc="best", labels = labs)
plt.show()  # leyendas %

# %%
plt = sns.barplot(x=labs, y = data[1])
plt.set(xlabel="Dia de la semana", ylabel= "Numero de vuelos")
# Out:
# [Text(0.5, 0, 'Dia de la semana'), Text(0, 0.5, 'Numero de vuelos')]

# %% [markdown]
# # GRAFICOS SERIES TEMPORALES

# %%
import datetime
import time

df = pd.read_csv("../../Tascas/Data/DelayedFlights.csv")
df2= df[df["Origin"].isin(["ATL","HOU","IND"])]
df = df.head(500000)

# %%
times = []
for i in np.arange(len(df)):
    times.append(datetime.datetime(year = 2008, month = df.loc[i,"Month"], day = df.loc[i,"DayofMonth"]))

# %%
times[50000]
# Out:
# datetime.datetime(2008, 1, 21, 0, 0)

# %%
df["Time"]= times

# %%
# agrupar por dias
data = df.groupby(by=["Time"], as_index=False)["DepDelay", "ArrDelay"].mean()
data.head()
# Out:
# <ipython-input-52-9a8ea684b2e9>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(by=["Time"], as_index=False)["DepDelay", "ArrDelay"].mean()
#         Time   DepDelay   ArrDelay
# 0 2008-01-01  45.251496  45.682020
# 1 2008-01-02  43.323846  41.279222
# 2 2008-01-03  38.315339  34.664569
# 3 2008-01-04  44.369113  42.175877
# 4 2008-01-05  47.647966  47.107071

# %%
sns.lineplot(data["Time"], data["DepDelay"])
# Out:
# /home/jesus/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Time', ylabel='DepDelay'>

# %%
data = df.groupby(by=["Time"])["DepDelay", "ArrDelay"].mean()
data.head()
# Out:
# <ipython-input-54-d821fb820e5c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(by=["Time"])["DepDelay", "ArrDelay"].mean()
#              DepDelay   ArrDelay
# Time
# 2008-01-01  45.251496  45.682020
# 2008-01-02  43.323846  41.279222
# 2008-01-03  38.315339  34.664569
# 2008-01-04  44.369113  42.175877
# 2008-01-05  47.647966  47.107071

# %%
sns.lineplot(data=data)
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
times = []
for i in df2.index:
    times.append(datetime.datetime(year = 2008, month = df2.loc[i,"Month"], day = df2.loc[i,"DayofMonth"]))

df2["Time"] = times

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="Time", y="ArrDelay", hue='Origin', data=df2)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='ArrDelay'>
